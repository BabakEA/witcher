# %% [markdown]
# Import the Libraries

# %%
import Recommender

# %%
import witcher
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
#from witcher import Recommender

# %% [markdown]
# Import Datasetes

# %%
df_C_Per_Product=Recommender.pd.read_csv('./data/Customer_per_product.csv',encoding='cp1252').drop_duplicates()
df_C_NPS_Extend=Recommender.pd.read_csv('./data/Customer_NPS_Extended.csv',encoding='cp1252').drop_duplicates()
df_C_NPS_Product=Recommender.pd.read_csv('./data/NPS_Customers_with_Products.csv',encoding='cp1252').drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-3669aed31dfd> in <module>
# ----> 1 df_C_Per_Product=Recommender.pd.read_csv('./data/Customer_per_product.csv',encoding='cp1252').drop_duplicates()
#       2 df_C_NPS_Extend=Recommender.pd.read_csv('./data/Customer_NPS_Extended.csv',encoding='cp1252').drop_duplicates()
#       3 df_C_NPS_Product=Recommender.pd.read_csv('./data/NPS_Customers_with_Products.csv',encoding='cp1252').drop_duplicates()
#
# AttributeError: module 'Recommender' has no attribute 'pd'

# %% [markdown]
# Generate the Recommender Model

# %%
Model_generator=Recommender.Model_Generator(df_C_Per_Product,df_C_NPS_Product,df_C_NPS_Extend,knn_neighbors=200)
# Out:
# Initial ......
#                              Fail  pass
# Popularity_based_suggestion    91    76
# User_similar                   33   134
# Products_neighbors             71    96
# Total                          29   138

# %%
Model_generator.Product_hist
# Out:
# ProductCode      PROD0001  PROD0002  PROD0008 PROD0011  PROD0015 PROD0019  \
# CustomerCIF
# CIF*&*00DWIGHT*         0         0         0        0         0        0
# CIF*&*00P.*MAHA         0         0         0        0         0        0
# CIF***00ABDOOL*  PROD0001  PROD0002  PROD0008        0         0        0
# CIF***00ACEDO*E  PROD0001  PROD0002         0        0  PROD0015        0
# CIF***00ACHONG*         0         0  PROD0008        0  PROD0015        0
# ...                   ...       ...       ...      ...       ...      ...
# CIFZRA01ORRETT*         0         0         0        0         0        0
# CIFZU*01JAHOOR*         0         0         0        0  PROD0015        0
# CIFZY*00PIERRE*         0         0         0        0         0        0
# CIFZY*00SIMON**         0         0  PROD0008        0  PROD0015        0
# CIFZY*01GORDON*         0         0         0        0  PROD0015        0
#
# ProductCode     PROD0021 PROD0024 PROD0029 PROD0030  ... PROD0420 PROD5008  \
# CustomerCIF                                          ...
# CIF*&*00DWIGHT*        0        0        0        0  ...        0        0
# CIF*&*00P.*MAHA        0        0        0        0  ...        0        0
# CIF***00ABDOOL*        0        0        0        0  ...        0        0
# CIF***00ACEDO*E        0        0        0        0  ...        0        0
# CIF***00ACHONG*        0        0        0        0  ...        0        0
# ...                  ...      ...      ...      ...  ...      ...      ...
# CIFZRA01ORRETT*        0        0        0        0  ...        0        0
# CIFZU*01JAHOOR*        0        0        0        0  ...        0        0
# CIFZY*00PIERRE*        0        0        0        0  ...        0        0
# CIFZY*00SIMON**        0        0        0        0  ...        0        0
# CIFZY*01GORDON*        0        0        0        0  ...        0        0
#
# ProductCode     PROD5011 PROD5030 PROD5057 PROD5180  PROD6008 PROD6015  \
# CustomerCIF
# CIF*&*00DWIGHT*        0        0        0        0         0        0
# CIF*&*00P.*MAHA        0        0        0        0         0        0
# CIF***00ABDOOL*        0        0        0        0         0        0
# CIF***00ACEDO*E        0        0        0        0  PROD6008        0
# CIF***00ACHONG*        0        0        0        0         0        0
# ...                  ...      ...      ...      ...       ...      ...
# CIFZRA01ORRETT*        0        0        0        0         0        0
# CIFZU*01JAHOOR*        0        0        0        0         0        0
# CIFZY*00PIERRE*        0        0        0        0         0        0
# CIFZY*00SIMON**        0        0        0        0         0        0
# CIFZY*01GORDON*        0        0        0        0         0        0
#
# ProductCode     PROD6030 PROD6180
# CustomerCIF
# CIF*&*00DWIGHT*        0        0
# CIF*&*00P.*MAHA        0        0
# CIF***00ABDOOL*        0        0
# CIF***00ACEDO*E        0        0
# CIF***00ACHONG*        0        0
# ...                  ...      ...
# CIFZRA01ORRETT*        0        0
# CIFZU*01JAHOOR*        0        0
# CIFZY*00PIERRE*        0        0
# CIFZY*00SIMON**        0        0
# CIFZY*01GORDON*        0        0
#
# [23965 rows x 111 columns]

# %%
Model_generator.ACC_report
# Out:
#                              Fail  pass
# Popularity_based_suggestion    91    76
# User_similar                   33   134
# Products_neighbors             71    96
# Total                          29   138

# %%
Model_generator.model_report
# Out:
#       Product Product_count USER Popularity_based_suggestion User_similar  \
# 0    PROD0008         51455    0                           1            1
# 1    PROD0008         51455    0                           0            1
# 2    PROD0002         62850    0                           0            0
# 3    PROD0088          8549    0                           0            0
# 4    PROD0121         79696    0                           1            1
# ..        ...           ...  ...                         ...          ...
# 162  PROD0038         39790    0                           1            1
# 163  PROD0054         11918    0                           1            1
# 164  PROD0214           361    0                           0            0
# 165  PROD0109         22652    0                           0            0
# 166  PROD0008         51455    0                           0            1
#
#     Products_neighbors Flag
# 0                    1    3
# 1                    1    2
# 2                    0    0
# 3                    0    0
# 4                    1    3
# ..                 ...  ...
# 162                  1    3
# 163                  1    3
# 164                  0    0
# 165                  0    0
# 166                  1    2
#
# [167 rows x 7 columns]

# %% [markdown]
# Recommnd new product to a Scotia's Client

# %%
products=Recommender.Product_Recommender("CIF***00ABDOOL*")
Recommender.pprint.pprint(products.report)
# Out:
# {'Popularity_based_suggestion': {'PROD0125': {'CustomerCount': 45029,
#                                               'ProductCode': 'PROD0125',
#                                               'ProductName': 'Credit Card '
#                                                              'Credit Health '
#                                                              'Insurance',
#                                               'SalesCategoryCornerstoneID': 'INSURANCE'}},
#  'User_similar': {'PROD0125': {'CustomerCount': 45029,
#                                'ProductCode': 'PROD0125',
#                                'ProductName': 'Credit Card Credit Health '
#                                               'Insurance',
#                                'SalesCategoryCornerstoneID': 'INSURANCE'}},
#  'products_neighbors': {'PROD0030': {'CustomerCount': 6692,
#                                      'ProductCode': 'PROD0030',
#                                      'ProductName': 'Term Deposit',
#                                      'SalesCategoryCornerstoneID': 'INVESTMENT'},
#                         'PROD0053': {'CustomerCount': 9103,
#                                      'ProductCode': 'PROD0053',
#                                      'ProductName': 'Small Business Chequing',
#                                      'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                         'PROD0089': {'CustomerCount': 16780,
#                                      'ProductCode': 'PROD0089',
#                                      'ProductName': 'Supplementary Credit Card',
#                                      'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                         'PROD0125': {'CustomerCount': 45029,
#                                      'ProductCode': 'PROD0125',
#                                      'ProductName': 'Credit Card Credit Health '
#                                                     'Insurance',
#                                      'SalesCategoryCornerstoneID': 'INSURANCE'}},
#  'user_product': {'PROD0001': {'CustomerCount': 58408,
#                                'ProductCode': 'PROD0001',
#                                'ProductName': 'Everyday Banking '
#                                               '(Transactional) OR Chequing '
#                                               'Accou',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                   'PROD0002': {'CustomerCount': 62850,
#                                'ProductCode': 'PROD0002',
#                                'ProductName': 'Savings Account',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                   'PROD0008': {'CustomerCount': 51455,
#                                'ProductCode': 'PROD0008',
#                                'ProductName': 'Credit Card',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                   'PROD0070': {'CustomerCount': 16869,
#                                'ProductCode': 'PROD0070',
#                                'ProductName': 'Insurance Savings',
#                                'SalesCategoryCornerstoneID': 'INVESTMENT'},
#                   'PROD0088': {'CustomerCount': 8549,
#                                'ProductCode': 'PROD0088',
#                                'ProductName': 'CC - Supplementary Card',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                   'PROD0124': {'CustomerCount': 46487,
#                                'ProductCode': 'PROD0124',
#                                'ProductName': 'Credit Card Credit Life '
#                                               'Insurance',
#                                'SalesCategoryCornerstoneID': 'INSURANCE'},
#                   'PROD0181': {'CustomerCount': 26127,
#                                'ProductCode': 'PROD0181',
#                                'ProductName': 'ASP Deposits',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'}}}

# %% [markdown]
# Recommnd a set of products to new customer

# %%
Requested_Products=["PROD0033",'PROD0052', 'PROD5057', 'PROD5180']
Income=[110000]
NPS=[0]

products=Recommender.Product_Recommender("test",NEW_USER="True",USER_feature=Requested_Products+Income+NPS)
Recommender.pprint.pprint(products.report)
# Out:
# {'Popularity_based_suggestion': {'PROD0126': {'CustomerCount': 6764,
#                                               'ProductCode': 'PROD0126',
#                                               'ProductName': 'Scotialine '
#                                                              'Credit Life '
#                                                              'Insurance',
#                                               'SalesCategoryCornerstoneID': 'INSURANCE'},
#                                  'PROD0127': {'CustomerCount': 6462,
#                                               'ProductCode': 'PROD0127',
#                                               'ProductName': 'Scotialine '
#                                                              'Credit health '
#                                                              'Insurance',
#                                               'SalesCategoryCornerstoneID': 'INSURANCE'}},
#  'User_similar': {'PROD0001': {'CustomerCount': 58408,
#                                'ProductCode': 'PROD0001',
#                                'ProductName': 'Everyday Banking '
#                                               '(Transactional) OR Chequing '
#                                               'Accou',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                   'PROD0002': {'CustomerCount': 62850,
#                                'ProductCode': 'PROD0002',
#                                'ProductName': 'Savings Account',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                   'PROD0008': {'CustomerCount': 51455,
#                                'ProductCode': 'PROD0008',
#                                'ProductName': 'Credit Card',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'},
#                   'PROD0070': {'CustomerCount': 16869,
#                                'ProductCode': 'PROD0070',
#                                'ProductName': 'Insurance Savings',
#                                'SalesCategoryCornerstoneID': 'INVESTMENT'},
#                   'PROD0092': {'CustomerCount': 7920,
#                                'ProductCode': 'PROD0092',
#                                'ProductName': 'Payroll',
#                                'SalesCategoryCornerstoneID': 'DAYTODAY'}},
#  'products_neighbors': {'PROD0107': {'CustomerCount': 20,
#                                      'ProductCode': 'PROD0107',
#                                      'ProductName': 'Small Business Letters of '
#                                                     'Guarantee',
#                                      'SalesCategoryCornerstoneID': 'BORROWING'},
#                         'PROD0176': {'CustomerCount': 3,
#                                      'ProductCode': 'PROD0176',
#                                      'ProductName': 'Group Benefits - SB / '
#                                                     'Commercial  (Life)',
#                                      'SalesCategoryCornerstoneID': 'INSURANCE'},
#                         'PROD6180': {'CustomerCount': 986,
#                                      'ProductCode': 'PROD6180',
#                                      'ProductName': 'ScotiaLine',
#                                      'SalesCategoryCornerstoneID': 'BORROWING'}},
#  'user_product': {'PROD0033': {'CustomerCount': 9,
#                                'ProductCode': 'PROD0033',
#                                'ProductName': 'Credit Life',
#                                'SalesCategoryCornerstoneID': 'INSURANCE'},
#                   'PROD0052': {'CustomerCount': 2061,
#                                'ProductCode': 'PROD0052',
#                                'ProductName': 'Small Business Term Loan',
#                                'SalesCategoryCornerstoneID': 'BORROWING'},
#                   'PROD5057': {'CustomerCount': 17,
#                                'ProductCode': 'PROD5057',
#                                'ProductName': 'Small Business Credit Line / '
#                                               'Overdraft New Funds (RWRT)',
#                                'SalesCategoryCornerstoneID': 'BORROWING'},
#                   'PROD5180': {'CustomerCount': 23,
#                                'ProductCode': 'PROD5180',
#                                'ProductName': 'ScotiaLine New Funds (RWRT)',
#                                'SalesCategoryCornerstoneID': 'BORROWING'}}}

# %%
Recommender.pprint.pprint(list(products.report["products_neighbors"].keys()))
# Out:
# ['PROD0176', 'PROD6180', 'PROD0107']
