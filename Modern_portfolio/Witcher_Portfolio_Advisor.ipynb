# %% [markdown]
# <h1 align="center">Witcher</h1>
# <h5 align="center">A code-free Magical Tool, which has designed to optimize and automate the analytical process</h5>
#
# **Portfolio_advisor is a new free feature that could create a winner portfolio.**
#
# ### How to use :
#
#
# 1. install the witcher
#     1. pip install witcher
# 2. Import the Portfolio advisor
# 	2. from witcher import Portfolio_Advisor
# 3. call the Magical function
# 	3. Portfolio=Portfolio_Advisor.Witcher_Portfolio()
# 4. bam : all set , there is no step 4 ! how cool is it ?
#
# <a href=https://www.youtube.com/channel/UCBqqRv8vWV3NZFF2tQV4e-w> Babak.EA</a>

# %%
# %%html
# <div align="center">
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Bo4tfIt-8H0" title="Witcher Portfolio advisor" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>
# Out:
# <div align="center">
# <iframe width="560" height="315" src="https://www.youtube.com/embed/Bo4tfIt-8H0" title="Witcher Portfolio advisor" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe></div>

# %%
from witcher import Portfolio_Advisor
# Out:
# Loading the Modern portfolio Optimizer powered by Witcher ....
# <style>div.output_scroll { height: 44em; }</style>

# %%
Portfolio=Portfolio_Advisor.Witcher_Portfolio()
# Out:
# interactive(children=(Output(),), _dom_classes=('widget-interact',))

# %% [markdown]
# ### Access to the Raw Data

# %%
Portfolio.Dataset.keys()
# Out:
# dict_keys(['retail', 'AAPL', 'COST', 'GO', 'SPY', 'SPOT', 'spy', 'Daily_return', 'cumul_return', 'cumul_return_percent', 'log_return', 'log_rets_cov', 'Final_Dataset', 'Best_points', 'PortFolio_Report'])

# %%
Portfolio.Dataset["PortFolio_Report"]
# Out:
# {'Gain': {'Portfolio': {'Absolute_Gain': 144.80084442138673,
#    'Percentage_Gain': 58.896913892931174},
#   'Market': {'Absolute_Gain': 105.3729248046875,
#    'Percentage_Gain': 34.0036516261948}},
#  'PLOT': {'MC': <bound method Portfolio_Analysis.__MC_plot of <witcher.Portfolio_Advisor.Portfolio_Analysis object at 0x00000280109F94C0>>,
#   '_MC': <bound method Portfolio_Analysis.__MC_PLT of <witcher.Portfolio_Advisor.Portfolio_Analysis object at 0x00000280109F94C0>>,
#   'Portfolio_vs_Market': <bound method Portfolio_Analysis.__Portfolio_vs_Market of <witcher.Portfolio_Advisor.Portfolio_Analysis object at 0x00000280109F94C0>>,
#   'Absolute': <bound method Portfolio_Analysis.__Absolute_Plot of <witcher.Portfolio_Advisor.Portfolio_Analysis object at 0x00000280109F94C0>>,
#   'Percentage': <bound method Portfolio_Analysis.__Percentage_Plot of <witcher.Portfolio_Advisor.Portfolio_Analysis object at 0x00000280109F94C0>>,
# ...

# %%
Portfolio.Dataset["retail"]
# Out:
#                   AAPL        COST         GO         SPY        SPOT  \
# 2020-06-10   87.121872  295.082581  33.970001  309.887085  189.399994
# 2020-06-11   82.939102  288.841644  33.160000  292.022430  178.679993
# 2020-06-12   83.655174  286.796539  32.630001  295.519623  180.070007
# 2020-06-15   84.689735  285.337097  33.150002  298.278442  187.880005
# 2020-06-16   86.934212  289.350494  34.700001  304.019653  185.479996
# ...                ...         ...        ...         ...         ...
# 2022-05-23  143.110001  429.480011  38.209999  396.920013  109.070000
# 2022-05-24  140.360001  437.709991  38.980000  393.890015  103.500000
# 2022-05-25  140.520004  440.109985  38.009998  397.369995  108.790001
# 2022-05-26  143.779999  464.989990  38.200001  405.309998  108.620003
# 2022-05-27  149.639999  470.760010  38.500000  415.260010  112.970001
#
#                    spy  Portfolio_dolar_value  PortFolio_Cumulative_Absolute  \
# ...

# %%
Portfolio.Dataset["Daily_return"]
# Out:
#                 AAPL      COST        GO       SPY      SPOT       spy  \
# 2020-06-11 -0.048011 -0.021150 -0.023845 -0.057649 -0.056600 -0.057649
# 2020-06-12  0.008634 -0.007080 -0.015983  0.011976  0.007779  0.011976
# 2020-06-15  0.012367 -0.005089  0.015936  0.009335  0.043372  0.009335
# 2020-06-16  0.026502  0.014065  0.046757  0.019248 -0.012774  0.019248
# 2020-06-17 -0.001392 -0.005807  0.023055 -0.004154  0.077367 -0.004154
# ...              ...       ...       ...       ...       ...       ...
# 2022-05-23  0.040119  0.031338  0.064049  0.018710  0.016780  0.018710
# 2022-05-24 -0.019216  0.019163  0.020152 -0.007634 -0.051068 -0.007634
# 2022-05-25  0.001140  0.005483 -0.024885  0.008835  0.051111  0.008835
# 2022-05-26  0.023200  0.056531  0.004999  0.019981 -0.001563  0.019981
# 2022-05-27  0.040757  0.012409  0.007853  0.024549  0.040048  0.024549
#
#             Port_folio_cumul_return_percent  Port_folio_Bol_MA  \
# ...
