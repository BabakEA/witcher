# %%
import witcher

# %%
help(witcher.StockMarket.Stock_Reader)
# Out:
# Help on function Stock_Reader in module witcher.StockMarket:
#
# Stock_Reader(stock=['AC.TO'], Period='1D', Start_date='2010-01-01', End_date='Today')
#     Input: Stock ID, starting and ending date
#     output: a Pandas data frame including daily stock values
#
#     Example: Stock_Reader(stock=["AC.TO"],Period="1D",Start_date="2010-01-01",End_date="Today")

# %%
df=witcher.StockMarket.Stock_Reader(stock=['AC.TO'], Period='1D', Start_date='2020-04-01', End_date='Today')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                  Open       High        Low      Close   Volume
# Date
# 2020-04-01  15.300000  15.550000  14.280000  14.460000  6336509
# 2020-04-02  14.510000  15.170000  14.040000  14.720000  4566433
# 2020-04-03  14.940000  15.040000  13.530000  14.550000  6858111
# 2020-04-06  15.240000  15.490000  14.860000  15.160000  5717319
# 2020-04-07  16.690001  17.500000  16.000000  16.570000  9164623
# ...               ...        ...        ...        ...      ...
# 2021-01-14  23.000000  24.350000  23.000000  23.889999  6969601
# 2021-01-15  23.650000  23.750000  22.850000  22.920000  5914343
# 2021-01-18  23.040001  23.330000  22.959999  22.969999  1748294
# 2021-01-19  23.200001  23.400000  22.950001  23.049999  3582055
# 2021-01-20  23.200001  23.549999  22.879999  22.889999  3488003
#
# [201 rows x 5 columns]

# %%
help(witcher.StockMarket)
# Out:
# Help on module witcher.StockMarket in witcher:
#
# NAME
#     witcher.StockMarket
#
# DESCRIPTION
#     ############################################
#     #### Date : 2021-01-17                ######
#     #### Author : Babak Emami             ######
#     ############################################
#
# CLASSES
#     builtins.object
#         AUTO_ARIMA
#         Dataset_Spliter
#
#     class AUTO_ARIMA(builtins.object)
#      |  AUTO_ARIMA(train=[1, 2, 3], test=[1, 2, 3], start_p=1, start_q=1, max_p=30, max_q=30, m=15, start_P=0, seasonal=True, d=1, D=1, trace=True, error_action='ignore', suppress_warnings=True, stepwise=True)
#      |
#      |  ***************************
#      |  Input: test Dataset, , train dataset, and AutoArima configurations
#      |
#      |  Exampl: Auto_Arima(train=report.train,test=reprt.test,start_p=1, start_q=1,
#      |                                 max_p=30, max_q=30, m=15,
#      |                                 start_P=0, seasonal=True,
# ...

# %%
witcher.StockMarket.Dataset_Spliter(df, col='Close', split=10, Forecasting=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[15]             : AIC=inf, Time=1.78 sec
#  ARIMA(0,1,0)(0,1,0)[15]             : AIC=580.287, Time=0.05 sec
#  ARIMA(1,1,0)(1,1,0)[15]             : AIC=541.109, Time=0.25 sec
#  ARIMA(0,1,1)(0,1,1)[15]             : AIC=inf, Time=1.16 sec
#  ARIMA(1,1,0)(0,1,0)[15]             : AIC=582.183, Time=0.05 sec
#  ARIMA(1,1,0)(2,1,0)[15]             : AIC=522.869, Time=0.56 sec
#  ARIMA(1,1,0)(2,1,1)[15]             : AIC=inf, Time=3.87 sec
#  ARIMA(1,1,0)(1,1,1)[15]             : AIC=inf, Time=1.34 sec
#  ARIMA(0,1,0)(2,1,0)[15]             : AIC=520.878, Time=0.38 sec
#  ARIMA(0,1,0)(1,1,0)[15]             : AIC=539.190, Time=0.12 sec
#  ARIMA(0,1,0)(2,1,1)[15]             : AIC=inf, Time=3.47 sec
#  ARIMA(0,1,0)(1,1,1)[15]             : AIC=inf, Time=2.08 sec
#  ARIMA(0,1,1)(2,1,0)[15]             : AIC=522.870, Time=0.88 sec
#  ARIMA(1,1,1)(2,1,0)[15]             : AIC=524.865, Time=3.78 sec
# ...
